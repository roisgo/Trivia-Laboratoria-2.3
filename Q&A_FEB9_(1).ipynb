# %% [markdown]
# <a href="https://colab.research.google.com/github/roisgo/Trivia-Laboratoria-2.3/blob/main/Q%26A_FEB9_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1import pandas as pd

df = pd.read_csv("music_project_en.csv")
df
# Out:
#          userID                              Track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre       City        time        Day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
df.columns[0] ## hOlACoMoEsTáS # este es un ejemplo de cosas que no se pueden hacer programáticamente...
# Out:
# '  userID'

# %%
## una pequeña lógica para poder entender cómo encontrar la primera mayúscula de una letra...

contador = 0
for letter in df.columns[0]:
    if letter.isupper():
        break
    contador+=1

contador
# Out:
# 6

# %%
## función para limpiar los nombres...

def fix_colnames(df):
    new_names = []
    for name in df.columns:
        new_names.append(name.lower().strip())
        
    return new_names

df.columns = fix_colnames(df)
df
# Out:
#          userid                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
## otras formas de modificar los nombres...
df.rename(columns = {"Track": "track", '  userID': "userid"})
# Out:
#          userid                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
## otra forma de modificar los nombres...

df.columns = ['userid', 'track', 'artist', 'genre', 'city', 'time', 'day']
df
# Out:
#          userid                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
a = [1,2,3,4,5]
sorted(a, reverse=True) # como ordenar una lista...
# Out:
# [5, 4, 3, 2, 1]

# %%
df["genre"].unique().sort_values() ## como NO ordenar (unique entrega un numpy array)

# %%
#forma 1
df["genre"].sort_values().unique()
# Out:
# array(['acid', 'acoustic', 'action', 'adult', 'africa', 'afrikaans',
#        'alternative', 'ambient', 'americana', 'animated', 'anime',
#        'arabesk', 'arabic', 'arena', 'argentinetango', 'art', 'audiobook',
#        'avantgarde', 'axé', 'baile', 'balkan', 'beats', 'bigroom',
#        'black', 'bluegrass', 'blues', 'bollywood', 'bossa', 'brazilian',
#        'breakbeat', 'breaks', 'broadway', 'cantautori', 'cantopop',
#        'canzone', 'caribbean', 'caucasian', 'celtic', 'chamber',
#        'children', 'chill', 'chinese', 'choral', 'christian', 'christmas',
#        'classical', 'classicmetal', 'club', 'colombian', 'comedy',
#        'conjazz', 'contemporary', 'country', 'cuban', 'dance',
#        'dancehall', 'dancepop', 'dark', 'death', 'deep', 'deutschrock',
#        'deutschspr', 'dirty', 'disco', 'dnb', 'documentary', 'downbeat',
#        'downtempo', 'drum', 'dub', 'dubstep', 'eastern', 'easy',
#        'electronic', 'electropop', 'emo', 'entehno', 'epicmetal',
# ...

# %%
# forma 2
import numpy as np
np.sort(df["genre"].astype(str).unique())
# Out:
# array(['acid', 'acoustic', 'action', 'adult', 'africa', 'afrikaans',
#        'alternative', 'ambient', 'americana', 'animated', 'anime',
#        'arabesk', 'arabic', 'arena', 'argentinetango', 'art', 'audiobook',
#        'avantgarde', 'axé', 'baile', 'balkan', 'beats', 'bigroom',
#        'black', 'bluegrass', 'blues', 'bollywood', 'bossa', 'brazilian',
#        'breakbeat', 'breaks', 'broadway', 'cantautori', 'cantopop',
#        'canzone', 'caribbean', 'caucasian', 'celtic', 'chamber',
#        'children', 'chill', 'chinese', 'choral', 'christian', 'christmas',
#        'classical', 'classicmetal', 'club', 'colombian', 'comedy',
#        'conjazz', 'contemporary', 'country', 'cuban', 'dance',
#        'dancehall', 'dancepop', 'dark', 'death', 'deep', 'deutschrock',
#        'deutschspr', 'dirty', 'disco', 'dnb', 'documentary', 'downbeat',
#        'downtempo', 'drum', 'dub', 'dubstep', 'eastern', 'easy',
#        'electronic', 'electropop', 'emo', 'entehno', 'epicmetal',
# ...

# %%
## partiendo desde cero nuevamente
df = pd.read_csv("music_project_en.csv")
df
# Out:
#          userID                              Track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre       City        time        Day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
## como no persistir los datos
# df = df.genre.replace("hip", "hip-hop") ## df.genre == df["genre"]

## como persistir los datos
df["genre"] = df.genre.replace("hip", "hip-hop") ## df.genre == df["genre"]
df
# Out:
#          userID                              Track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre       City        time        Day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
## para persistir los cambios, siempre debo identificar la estructura y guardarla en la misma estructura...
df.columns = fix_colnames(df)
df.isnull().sum()  # como puedo colocar unknown en los campos donde está nulo/ausente...
# Out:
# userid       0
# track     1343
# artist    7567
# genre     1198
# city         0
# time         0
# day          0
# dtype: int64

# %% [markdown]
# ## Algunos ejemplos con FILLNA

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.fillna("unknown").isnull().sum() 
## fillna para dataframes, es que en un paso relleno todo, pero utilizo el mismo relleno para todas las columnas
# Out:
# userid    0
# track     0
# artist    0
# genre     0
# city      0
# time      0
# day       0
# dtype: int64

# %%
df["artist"].fillna("unknown")
df["track"].fillna("unknown")
df["genre"].fillna("unknown")

## hardcoding... estoy explicitamente dando los valores que voy a cambiar...

# %%
columns_to_replace = ["track", "artist", "genre"]

for column in columns_to_replace:
    df[column] = df[column].fillna("unknown")

# %%
## .fillna es un método es una función que sirve sólo para un tipo de objeto, y se llama con punto...

df.describe()

# %%
a = [1,2,3]
df.describe() # métodos modifican o calculan algo...
# Out:
#           userid    track   artist  genre         city      time     day
# count      65079    65079    65079  65079        65079     65079   65079
# unique     41748    39667    37807    268            2     20392       3
# top     A8AE9169  unknown  unknown    pop  Springfield  08:14:07  Friday
# freq          76     1343     7567   8850        45360        14   23149

# %%
sorted(a) # función...

# atributos muestran información pero no modifican nada...
df.shape
df.columns
df.size
df.genre.name
# Out:
# 'genre'

# %% [markdown]
# ## Ejemplos de if incorrectos

# %%
# no funciona
if df.city == "Shellbyville": 
    print("éxito")
else:
    print("fracaso")
    
##
# Out:
# fracaso

# %%
# sí funciona
success = []

for item in df.city:
    if item == "Shelbyville":
        success.append("éxito")
    else:
        success.append("fracaso")
        
## y como guardarian esto en una serie que sea parte del dataframe...

df["success"] = success
df
# Out:
#          userid                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina           unknown
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day  success
# 0            rock  Shelbyville  20:28:33  Wednesday    éxito
# ...

# %%
df["success_v2"] = success[:100]  # para columnas en pandas deben tener el número correcto de elementos...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/datacuber/Documents/practicum/Q&A_FEB9.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/datacuber/Documents/practicum/Q%26A_FEB9.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> df["success_v2"] = success[:100]
#
# File ~/miniconda3/envs/dl/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/miniconda3/envs/dl/lib/python3.9/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# ...

# %%
# empezamos de nuevo
df = pd.read_csv("music_project_en.csv")
df.columns = fix_colnames(df)
df
# Out:
#          userid                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina               NaN
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
## ejemplo utilizando any... también recordar que existe el opuesto que es all...
for column in df.columns:
    if df[column].isnull().any():
        df[column] = df[column].fillna("unknown")


#ejemplo para ejecutar una funcion y corregir nombres duplicados 
def replace_wrong_values(wrong_values, correct_value): # pasamos una lista de valores incorrectos y una string con el valor correcto en la entrada de la función
    for wrong_value in wrong_values: # un bucle sobre nombres mal escritos
        tennis['name'] = tennis['name'].replace(wrong_value, correct_value) # llamamos a replace() por cada nombre incorrecto

duplicates = ['Roger Federerr', 'Roger Fedrer'] # una lista de nombres mal escritos
name = 'Roger Federer' # el nombre correcto
replace_wrong_values(duplicates, name) # llamamos a la función, replace() se llamará dos veces
print(tennis) # el nuevo DataFrame sin duplicados 

# ejemplo para reemplazar nombres
import pandas as pd

column_names = ['date','position','price']
orders = [
    ['2021.05.12',    'Orange juice', 100],
    ['2021.05.12',    'Margherita pizza',  300],
    ['2021.05.12',    'Vanilla ice-cream', 150],
    ['2021.05.12',    'Pizza margherita ', 100]
]
cafe = pd.DataFrame(data=orders, columns=column_names) 
cafe['position'] = cafe['position'].replace('Pizza Margherita', 'Margherita pizza') 



#para encontrar el numero de planetas en donde se proporciona el radio
exo_number = exoplanet.groupby('discovered')['radius'].count()
print(exo_number) 

#para encontrar la suma de los radios
exo_radius_sum = exoplanet.groupby('discovered')['radius'].sum()
print(exo_radius_sum) 

#dividir la syuma de los radios entre el no de exoplanetas descubiertos sin utilizar bucle
exo_radius_mean = exo_radius_sum/exo_number
print(exo_radius_mean) 

#ordenar los radios en forma ascendente
print(exoplanet.sort_values(by='radius').head(10)) 

#código que ordena la columna de radios e imprime los primeros 10 resultados:
print(exoplanet['radius'].sort_values().head(10)) 

#Obtengamos todos los exoplanetas cuyos radios son más pequeños que el de la Tierra. La indexación lógica nos ayudará en esto:
print(exoplanet[exoplanet['radius'] < 1]) 

#Ahora, supongamos que solo nos interesan los valores para 2014:
print(exoplanet[exoplanet['discovered'] == 2014]) 

# exoplanetas más pequeños que la Tierra __ y __ descubiertas en 2014
exo_small_14 = exoplanet[exoplanet['radius'] < 1]
exo_small_14 = exo_small_14[exo_small_14['discovered'] == 2014]
print(exo_small_14) 

#Ordenemos el resultado por radio en orden descendente.
print(exo_small_14.sort_values(by='radius', ascending=False)) 

#Como habrás notado, sort_values() devuelve un nuevo objeto en vez de modificarlo en su lugar. Por lo tanto, si deseas seguir trabajando con el DataFrame ordenado deberás almacenar el resultado en una variable. Puedes volver a guardarlo en la misma:
exo_small_14 = exo_small_14.sort_values(by='radius', ascending=False) 

#ESTADISTICA DESCRIPTIVA
#Obtengamos el máximo y el mínimo para el tiempo de reproducción de cada canción en segundos (la columna 'total_play_seconds'). Para encontrar el valor máximo llama al método max():
print(df['total_play_seconds'].max()) 

#Afortunadamente, podemos averiguarlo mediante la indexación lógica. Mostramos la fila del DataFrame para la que 'total_play_seconds' es igual al valor máximo:
print(df[df['total_play_seconds'] == df['total_play_seconds'].max()]) 

#Hagamos un segmento de las pistas escuchadas durante más de medio minuto y busquemos el valor mínimo:
df_drop_skip = df[df['total_play_seconds'] > 30] 
print(df_drop_skip['total_play_seconds'].min()) 

#Ahora obtendremos los nombres de las pistas que se saltaron rápidamente. Aplicaremos la indexación lógica como cuando buscábamos el valor máximo:
print(df_drop_skip[df_drop_skip['total_play_seconds'] == df_drop_skip['total_play_seconds'].min()]) 

#pandas tiene un método llamado median() que calcula medianas. Al igual que min() y max(), se puede aplicar a toda la tabla, una columna o datos agrupados.
print(df_stat['total_play_seconds'].median()) 

#Ahora podemos aplicar la mediana a todos los valores de duración de escucha en nuestra tabla, con la excepción de las pistas que se omitieron:
df_drop_skip = df[df['total_play_seconds'] > 30]
print(df_drop_skip['total_play_seconds'].median()) 

#MEDIA
print(df_drop_skip['total_play_seconds'].mean())

# %%
df.isnull().sum()
# Out:
# userid    0
# track     0
# artist    0
# genre     0
# city      0
# time      0
# day       0
# dtype: int64
